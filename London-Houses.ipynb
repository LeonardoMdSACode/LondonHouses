# %%
import pandas as pd

# %%
data=pd.read_csv("london_houses.csv")
data
# Out:
#                    Address  Neighborhood  Bedrooms  Bathrooms  Square Meters  \
# 0         78 Regent Street  Notting Hill         2          3            179
# 1        198 Oxford Street   Westminster         2          1            123
# 2         18 Regent Street          Soho         5          3            168
# 3     39 Piccadilly Circus     Islington         5          1            237
# 4         116 Fleet Street    Marylebone         4          1            127
# ..                     ...           ...       ...        ...            ...
# 995  44 Camden High Street   Westminster         1          3             81
# 996          165 Park Lane        Camden         1          1             65
# 997  99 Camden High Street        Camden         4          1            191
# 998          155 Park Lane        Camden         5          2            131
# 999       145 Baker Street    Kensington         4          2            185
#
# ...

# %%
data.head()
# Out:
#                 Address  Neighborhood  Bedrooms  Bathrooms  Square Meters  \
# 0      78 Regent Street  Notting Hill         2          3            179
# 1     198 Oxford Street   Westminster         2          1            123
# 2      18 Regent Street          Soho         5          3            168
# 3  39 Piccadilly Circus     Islington         5          1            237
# 4      116 Fleet Street    Marylebone         4          1            127
#
#    Building Age Garden Garage  Floors  Property Type        Heating Type  \
# 0            72     No     No       3  Semi-Detached    Electric Heating
# 1            34    Yes     No       1      Apartment     Central Heating
# 2            38     No    Yes       3  Semi-Detached     Central Heating
# 3            53    Yes    Yes       1      Apartment  Underfloor Heating
# 4            23     No    Yes       2  Semi-Detached     Central Heating
#
#               Balcony Interior Style    View          Materials  \
# ...

# %%
data.describe()
# Out:
#           Bedrooms    Bathrooms  Square Meters  Building Age       Floors  \
# count  1000.000000  1000.000000      1000.0000    1000.00000  1000.000000
# mean      3.013000     2.003000       149.6270      49.96500     1.991000
# std       1.393834     0.808483        58.0562      29.07086     0.821946
# min       1.000000     1.000000        50.0000       1.00000     1.000000
# 25%       2.000000     1.000000        99.0000      24.00000     1.000000
# 50%       3.000000     2.000000       148.0000      50.00000     2.000000
# 75%       4.000000     3.000000       201.0000      76.00000     3.000000
# max       5.000000     3.000000       249.0000      99.00000     3.000000
#
#           Price (£)
# count  1.000000e+03
# mean   1.840807e+06
# std    8.793484e+05
# min    3.866660e+05
# 25%    1.161400e+06
# 50%    1.721999e+06
# 75%    2.390500e+06
# max    4.980000e+06

# %%
data.describe(include="O")
# Out:
#                Address Neighborhood Garden Garage   Property Type  \
# count             1000         1000   1000   1000            1000
# unique             770           10      2      2               3
# top     96 King's Road   Kensington    Yes    Yes  Detached House
# freq                 4          114    512    501             349
#
#             Heating Type     Balcony Interior Style  View Materials  \
# count               1000        1000           1000  1000      1000
# unique                 4           3              4     5         4
# top     Electric Heating  No Balcony        Classic   Sea      Wood
# freq                 266         340            263   210       264
#
#        Building Status
# count             1000
# unique               3
# top          Renovated
# freq               341

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Address          1000 non-null   object
#  1   Neighborhood     1000 non-null   object
#  2   Bedrooms         1000 non-null   int64
#  3   Bathrooms        1000 non-null   int64
#  4   Square Meters    1000 non-null   int64
#  5   Building Age     1000 non-null   int64
#  6   Garden           1000 non-null   object
#  7   Garage           1000 non-null   object
#  8   Floors           1000 non-null   int64
#  9   Property Type    1000 non-null   object
#  10  Heating Type     1000 non-null   object
#  11  Balcony          1000 non-null   object
#  12  Interior Style   1000 non-null   object
#  13  View             1000 non-null   object
#  14  Materials        1000 non-null   object
#  15  Building Status  1000 non-null   object
#  16  Price (£)        1000 non-null   int64
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data["Price (£)"].agg(["max", "min", "mean"])
# Out:
# max     4980000.000
# min      386666.000
# mean    1840807.278
# Name: Price (£), dtype: float64

# %%
data[data["Price (£)"]==4980000.000]
# Out:
#              Address Neighborhood  Bedrooms  Bathrooms  Square Meters  \
# 86  77 Oxford Street      Chelsea         5          2            249
#
#     Building Age Garden Garage  Floors   Property Type     Heating Type  \
# 86             3    Yes     No       2  Detached House  Central Heating
#
#                Balcony Interior Style View Materials Building Status  \
# 86  High-level Balcony     Minimalist  Sea      Wood       Renovated
#
#     Price (£)
# 86    4980000

# %%
data[data["Price (£)"]==386666.000]
# Out:
#                    Address Neighborhood  Bedrooms  Bathrooms  Square Meters  \
# 106  146 Piccadilly Circus    Greenwich         2          3             58
#
#      Building Age Garden Garage  Floors Property Type     Heating Type  \
# 106            47    Yes     No       1     Apartment  Central Heating
#
#                 Balcony Interior Style  View Materials Building Status  \
# 106  High-level Balcony     Industrial  Park      Wood       Renovated
#
#      Price (£)
# 106     386666

# %% [markdown]
# ***The price per square meter***

# %%
data["Price per meter"]=(data["Price (£)"] / data["Square Meters"])-round(2)
data
# Out:
#                    Address  Neighborhood  Bedrooms  Bathrooms  Square Meters  \
# 0         78 Regent Street  Notting Hill         2          3            179
# 1        198 Oxford Street   Westminster         2          1            123
# 2         18 Regent Street          Soho         5          3            168
# 3     39 Piccadilly Circus     Islington         5          1            237
# 4         116 Fleet Street    Marylebone         4          1            127
# ..                     ...           ...       ...        ...            ...
# 995  44 Camden High Street   Westminster         1          3             81
# 996          165 Park Lane        Camden         1          1             65
# 997  99 Camden High Street        Camden         4          1            191
# 998          155 Park Lane        Camden         5          2            131
# 999       145 Baker Street    Kensington         4          2            185
#
# ...

# %% [markdown]
# ***The Total Rooms in House***

# %%
data["Total Rooms"]=data["Bedrooms"]+data["Bathrooms"]
data
# Out:
#                    Address  Neighborhood  Bedrooms  Bathrooms  Square Meters  \
# 0         78 Regent Street  Notting Hill         2          3            179
# 1        198 Oxford Street   Westminster         2          1            123
# 2         18 Regent Street          Soho         5          3            168
# 3     39 Piccadilly Circus     Islington         5          1            237
# 4         116 Fleet Street    Marylebone         4          1            127
# ..                     ...           ...       ...        ...            ...
# 995  44 Camden High Street   Westminster         1          3             81
# 996          165 Park Lane        Camden         1          1             65
# 997  99 Camden High Street        Camden         4          1            191
# 998          155 Park Lane        Camden         5          2            131
# 999       145 Baker Street    Kensington         4          2            185
#
# ...

# %% [markdown]
# **Mapping to simplified**

# %%
data["Garage"]=data["Garage"].map({"Yes":1,"No":0})
data["Garage"]=data["Garage"].map({"Yes":1,"No":0})
data
# Out:
#                    Address  Neighborhood  Bedrooms  Bathrooms  Square Meters  \
# 0         78 Regent Street  Notting Hill         2          3            179
# 1        198 Oxford Street   Westminster         2          1            123
# 2         18 Regent Street          Soho         5          3            168
# 3     39 Piccadilly Circus     Islington         5          1            237
# 4         116 Fleet Street    Marylebone         4          1            127
# ..                     ...           ...       ...        ...            ...
# 995  44 Camden High Street   Westminster         1          3             81
# 996          165 Park Lane        Camden         1          1             65
# 997  99 Camden High Street        Camden         4          1            191
# 998          155 Park Lane        Camden         5          2            131
# 999       145 Baker Street    Kensington         4          2            185
#
# ...

# %% [markdown]
# ****New Tables****

# %%
Neighborhood=data.pivot_table(index="Neighborhood",values="Price (£)", aggfunc=["max", "min", "mean"])
Neighborhood
# Out:
#                    max       min          mean
#              Price (£) Price (£)     Price (£)
# Neighborhood
# Camden         2977000    450666  1.626332e+06
# Chelsea        4980000    760000  2.452894e+06
# Greenwich      2470000    386666  1.269409e+06
# Islington      2916000    512000  1.507373e+06
# Kensington     4427000    671333  2.282233e+06
# Marylebone     3585000    530000  1.824982e+06
# Notting Hill   3936000    682666  1.957589e+06
# Shoreditch     2706000    388666  1.332829e+06
# Soho           3472000    532000  1.781121e+06
# Westminster    4482000    672000  2.291437e+06

# %%
Materials=data.pivot_table(index="Materials", values="Price (£)", aggfunc=["max", "min", "mean"])
Materials
# Out:
#                         max       min          mean
#                   Price (£) Price (£)     Price (£)
# Materials
# Granite             4200000    410666  1.815444e+06
# Laminate Flooring   4338000    462000  1.830937e+06
# Marble              4482000    388666  1.770287e+06
# Wood                4980000    386666  1.937941e+06

# %%
import numpy as np

# %%
data.shape
# Out:
# (1000, 19)

# %%
data.isnull().sum()
# Out:
# Address               0
# Neighborhood          0
# Bedrooms              0
# Bathrooms             0
# Square Meters         0
# Building Age          0
# Garden                0
# Garage             1000
# Floors                0
# Property Type         0
# Heating Type          0
# Balcony               0
# Interior Style        0
# View                  0
# Materials             0
# Building Status       0
# Price (£)             0
# Price per meter       0
# Total Rooms           0
# dtype: int64
